# %%
# %pip install pandas numpy scikit-learn xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
import xgboost as xgb

# %%
# Load the dataset
df = pd.read_csv('insurance_dataset.csv')

# %%
# Create a copy of the dataframe for feature engineering
df_work = df.copy()

# %%
df.sample(5)
# Out:
#       age     sex   bmi  children smoker     region   premium
# 569    48    male  40.6         2    yes  northwest  45702.02
# 260    58  female  25.2         0     no  southwest  11837.16
# 112    37    male  30.8         0     no  southwest   4646.76
# 131    61  female  22.0         0     no  northeast  13616.36
# 1310   42    male  26.3         1     no  northwest   6940.91

# %%
df_work['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
# Geature BMI Category :
def bmi_category(bmi):
    if bmi<18.5:
        return "underweight"
    elif bmi<25:
        return "normal"
    elif bmi<30:
        return "overweight"
    else:
        return "obese"
df_work["bmi_category"]=df_work["bmi"].apply(bmi_category)

# %%
# Feature 2: Smoking Risk
def smoking_risk(row):
    if row["smoker"] == "yes" and row["bmi"] > 30:
        return "high"
    elif row["smoker"] == "yes" or row["bmi"] > 27:
        return "medium"
    else:
        return "low"

df_work["smoking_risk"] = df_work.apply(smoking_risk, axis=1)

# %%
df_work.head(5)
# Out:
#    age     sex   bmi  children smoker     region   premium bmi_category  \
# 0   19  female  27.9         0    yes  southwest  16884.92   overweight
# 1   18    male  33.8         1     no  southeast   1725.55        obese
# 2   28    male  33.0         3     no  southeast   4449.46        obese
# 3   33    male  22.7         0     no  northwest  21984.47       normal
# 4   32    male  28.9         0     no  northwest   3866.86   overweight
#
#   smoking_risk
# 0       medium
# 1       medium
# 2       medium
# 3          low
# 4       medium

# %%
# Select features and target
X = df_work[["age", "sex", "children", "region", "bmi_category", "smoking_risk"]]
y = df_work["premium"]

# %%
# Define categorical and numeric features
categorical_features = ["sex", "region", "bmi_category", "smoking_risk"]
numeric_features = ["age", "children"]

# %%
# Create column transformer for OHE
preprocessor = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_features),
        ("num", "passthrough", numeric_features)
    ]
)

# %%
# Create a pipeline with preprocessing and XGBoost regressor
pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("regressor", xgb.XGBRegressor(random_state=42))
])

# %%
# Split data with 88% train and 12% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=1)

# %%
# Train the model
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sex', 'region',
#                                                    'bmi_category',
#                                                    'smoking_risk']),
#                                                  ('num', 'passthrough',
#                                                   ['age', 'children'])])),
#                 ('regressor',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=Non...
#                               feature_types=None, feature_weights=None,
# ...

# %%
# Predict on test set
y_pred = pipeline.predict(X_test)
# Out:
# C:\Users\mayan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_encoders.py:261: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(msg, UserWarning)

# %%
 # Calculate MAPE and RMSE
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
# Print evaluation metrics
print(f"MAPE: {mape:.4f}")
print(f"RMSE: {rmse:.2f}")
# Out:
# MAPE: 0.4355
# RMSE: 6937.83

# %%
# Save the trained pipeline
import pickle
with open("xgboost_insurance_model.pkl", "wb") as f:
    pickle.dump(pipeline, f)

# %%
def calculate_risk_score(row):
    score = 0

    if row["age"] > 50:
        score += 3

    elif row["age"] > 30:
        score += 2

    else:
        score += 1

    if row["bmi"] > 30:
        score += 3

    elif row["bmi"] > 25:
        score += 2

    else:
        score += 1

    if row["smoker"] == "yes":
        score += 4

    return score

df_work["risk_score"] = df_work.apply(
    calculate_risk_score,
    axis=1
)

# %%
def risk_category(score):

    if score <= 3:
        return "Low"

    elif score <= 6:
        return "Medium"

    else:
        return "High"

# %%
df_work["health_risk"] = df_work[
    "risk_score"
].apply(risk_category)

# %%
df_work.head()
# Out:
#    age     sex   bmi  children smoker     region   premium bmi_category  \
# 0   19  female  27.9         0    yes  southwest  16884.92   overweight
# 1   18    male  33.8         1     no  southeast   1725.55        obese
# 2   28    male  33.0         3     no  southeast   4449.46        obese
# 3   33    male  22.7         0     no  northwest  21984.47       normal
# 4   32    male  28.9         0     no  northwest   3866.86   overweight
#
#   smoking_risk  risk_score health_risk
# 0       medium           7        High
# 1       medium           4      Medium
# 2       medium           4      Medium
# 3          low           3         Low
# 4       medium           4      Medium

# %%
df_work.to_csv(
    "insurance_enhanced.csv",
    index=False
)

# %%
#  model 1 : Premium model :
y_premium = df["premium"]

# %%
#  Risk Score Model :
y_score = df_work["risk_score"]

# %%
#  Health Score Model :
y_risk = df_work["health_risk"]

# %%
X = df_work[
    [
        "age",
        "sex",
        "children",
        "region",
        "bmi_category",
        "smoking_risk"
    ]
]

# %%
premium_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", xgb.XGBRegressor())
])

premium_pipeline.fit(X, y_premium)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sex', 'region',
#                                                    'bmi_category',
#                                                    'smoking_risk']),
#                                                  ('num', 'passthrough',
#                                                   ['age', 'children'])])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, de...
#                               feature_types=None, feature_weights=None,
# ...

# %%
score_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", xgb.XGBRegressor())
])

score_pipeline.fit(X, y_score)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sex', 'region',
#                                                    'bmi_category',
#                                                    'smoking_risk']),
#                                                  ('num', 'passthrough',
#                                                   ['age', 'children'])])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, de...
#                               feature_types=None, feature_weights=None,
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

y_risk_encoded = le.fit_transform(y_risk)

# %%
risk_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", xgb.XGBClassifier())
])

risk_pipeline.fit(X, y_risk_encoded)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sex', 'region',
#                                                    'bmi_category',
#                                                    'smoking_risk']),
#                                                  ('num', 'passthrough',
#                                                   ['age', 'children'])])),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, d...
#                                feature_types=None, feature_weights=None,
# ...

# %%
print(df_work.columns)
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'premium',
#        'bmi_category', 'smoking_risk', 'risk_score', 'health_risk'],
#       dtype='object')

# %%
premium = premium_pipeline.predict(df_work)[0]

score = score_pipeline.predict(df_work)[0]

risk_encoded = risk_pipeline.predict(df_work)[0]

# risk = le.inverse_transform([risk_encoded])[0]

# %%
print(premium)
print(score)
print(risk)
# Out:
# 8775.628
# 4.8702745
# Low

# %%
with open("insurance_premium.pkl", "wb") as f:
    pickle.dump(premium_pipeline, f)

# %%
with open("score.pkl", "wb") as f:
    pickle.dump(score_pipeline, f)

# %%
with open("risk.pkl", "wb") as f:
    pickle.dump(risk_pipeline, f)
